# %% [markdown]
# <h1>배열과 리스트의 비교</h1>

# %% [markdown]
# <h2>개발 환경</h2>
# <table border=2 >
# <tr align="center" bgcolor="#3d0454"><td><font><b>언어</b></font></td><td><font><b>IDE</b></font></td><td><font><b>사용한 라이브러리</b></font></td><td><font><b>역할</b></font></td></tr>
# <tr align="center"><td><font>C++</font></td><td><font>Visual Studio</font></td><td><font>iostream, fstream, string.h</font></td><td><font>알고리즘 개발 및 파일 입출력<font></td></tr>
# <tr align="center"><td><font>Python</font></td><td><font>Visual Studio Code</font></td><td><font>pandas, matplotlib</font></td><td><font>데이터 시각화 및 csv파일 불러오기</font></td></tr>
# </table>

# %% [markdown]
# <h2>Push했을 때 배열과 리스트의 크기

# %%
import pandas as pd
import matplotlib.pylab as plt
from matplotlib import font_manager as fm

plt.rcParams['font.family']=fm.FontProperties(fname='C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\BMDOHYEON_ttf.ttf').get_name()

df=pd.read_csv("size.csv",encoding="EUC-KR",index_col=0)
minsize=df["배열"].min()
maxsize=df["배열"].max()
plt.title("배열과 리스트의 삽입별 크기")
plt.grid(True)
plt.yticks(range(minsize,maxsize+1,4),[str(num)+" Byte" for num in range(minsize,maxsize+1,4)])
plt.xticks(range(1,11),[str(count)+"회" for count in range(1,11)])
plt.plot(df.index,df["리스트"],label="리스트",marker ="o")
plt.plot(df.index,df["배열"],label="배열",marker ="o")
plt.legend()
plt.show()

# %% [markdown]
# <h2>Push 했을 때 리스트와 배열의 시간 복잡도

# %%
import pandas as pd
import matplotlib.pylab as plt
import matplotlib.font_manager as fm

plt.rcParams['font.family']=fm.FontProperties(fname='C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\BMDOHYEON_ttf.ttf').get_name()


df=pd.read_csv("push.csv",encoding='euc-kr',index_col=0)
plt.title("Push시 배열과 리스트의 시간 복잡도")
plt.plot(df.index,df["배열"],'ro',label="배열")
plt.plot(df.index,df["리스트"],label="리스트")
plt.xticks(range(1,11), [str(count)+"회" for count in range(1,11)])
plt.yticks(range(1,11),["O("+str(num)+")" for num in range(1,11)])
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# <h2>Pop했을 때 리스트와 배열의 시간 복잡도

# %%
import pandas as pd
import matplotlib.pylab as plt
import matplotlib.font_manager as fm

plt.rcParams['font.family']=fm.FontProperties(fname='C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\BMDOHYEON_ttf.ttf').get_name()

df=pd.read_csv("Pop.csv",encoding='euc-kr',index_col=0)
plt.title("Pop했을 때 배열과 리스트의 시간 복잡도")
plt.plot(df.index,df["배열"],'ro',label="배열")
plt.plot(df.index,df["리스트"],label="리스트")
plt.xticks(range(1,11), [str(count)+"회" for count in range(1,11)])
plt.yticks(range(1,11),["O("+str(num)+")" for num in range(1,11)])
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# <h2>DeQueue했을 때 리스트와 배열의 시간 복잡도

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import pandas as pd

plt.rcParams['font.family']=fm.FontProperties(fname='C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\BMDOHYEON_ttf.ttf').get_name()

df=pd.read_csv('DeQueue.csv',encoding='EUC-KR',index_col=0)

plt.plot(df.index,df["배열"],"ro-",label="배열")
plt.plot(df.index,df["리스트"],"bo-",label="리스트")
plt.title("DeQueue했을 때 배열과 리스트의 시간 복잡도")

plt.xticks(range(1,10), [str(count)+"회" for count in range(1,10)])
plt.yticks(range(1,10),["O("+str(num)+")" for num in range(1,10)])
plt.legend()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 13
#      10 plt.plot(df.index,df["리스트"],"bo-",label="리스트")
#      11 plt.title("DeQueue했을 때 배열과 리스트의 시간 복잡도")
# ---> 13 plt.xticks(range(1,11), [str(count)+"회" for count in range(1,10)])
#      14 plt.yticks(range(1,11),["O("+str(num)+")" for num in range(1,10)])
#      15 plt.legend()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:1866, in xticks(ticks, labels, minor, **kwargs)
#    1864         l._internal_update(kwargs)
#    1865 else:
# -> 1866     labels = ax.set_xticklabels(labels, minor=minor, **kwargs)
#    1868 return locs, labels
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_api\deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axis.py:1973, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    1969 if isinstance(locator, mticker.FixedLocator):
#    1970     # Passing [] as a list of labels is often used as a way to
#    1971     # remove all tick labels, so only error for > 0 labels
#    1972     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 1973         raise ValueError(
#    1974             "The number of FixedLocator locations"
#    1975             f" ({len(locator.locs)}), usually from a call to"
#    1976             " set_ticks, does not match"
#    1977             f" the number of labels ({len(labels)}).")
#    1978     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    1979     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (10), usually from a call to set_ticks, does not match the number of labels (9).

# %% [markdown]
# <h2>최대 메모리

# %%
import pandas as pd
import matplotlib.pylab as plt
from matplotlib import font_manager as fm

plt.rcParams['font.family']=fm.FontProperties(fname='C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\BMDOHYEON_ttf.ttf').get_name()

df=pd.read_csv("size.csv", encoding="EUC-KR",index_col=0)
y=[df["배열"].max(),df["리스트"].max()]
x=["배열","리스트"]
plt.title("최대 메모리")
plt.xlabel("종류")
plt.ylabel("크기")
plt.yticks(range(0,max(y[0],y[1])+4,4))
plt.text(0.75,36,"단위 : Byte",size=20)
plt.text(0.9,8,f"{y[1]}Byte")
plt.text(-0.085,8,f"{y[0]}Byte")
plt.bar(x,y,color=['red','blue'])
plt.show()

# %% [markdown]
# <h2>결론</h2>
# 정수형 배열과 정수형 리스트를 비교해본 결과<br>
# <strong>메모리 면에서는 요소의 갯수가 4개 이하면 리스트 보다는 배열</strong>을 사용하는것이 효율적임<br>
# 하지만 <strong>시간 복잡도나 요소의 갯수가 5개 이상이면 배열보다는 리스트</strong>를 사용하는 것이 훨씬 효율적임<br>

# %% [markdown]
# <h2>배운 점</h2>
# <ol>
# <li><strong>Python의 라이브러리인 matplotlib와 pandas의 기초</strong>를 알게 됨<br>
# <li><strong>C++로 콘솔 프로그램만 개발 하였으나 파일입출력을 이용해서 콘솔 프로그램이 아닌 프로그램을 제작을 해 봄</strong>
# </ol>

# %% [markdown]
# <h2>발전하고 싶은 점</h2>
# <ol>
# <li>C/C++ 개발을 visual studio가 아닌 visual studio code에 해보고 싶음
# <li>Mysql과 C++를 연동하는 법을 알아보고 싶음
# <li>Python으로 AI 개발 및 데이터 수집에 대해 배워보고 싶음
# </ol>
